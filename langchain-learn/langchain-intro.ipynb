# %% [markdown]
# #### Langchain Starts
# This notebook shows how to use `langchain_ollama` to connect LangChain to a locally running Ollama runtime at `http://localhost:11434`.
# No OpenAI API key is needed; the model runs locally on your machine.

# %%
import os
from langchain_ollama import ChatOllama

# Create a local Ollama client that connects to the Ollama runtime on localhost
llm = ChatOllama(
    model='llama3.2:3b',
    base_url='http://localhost:11434',
    validate_model_on_init=False,
)

# Run a simple local prompt with LangChain's Ollama client
response = llm.invoke('Explain how LangChain connects to Ollama locally in one sentence.')
print(response.content)

# Experiment with your own question
question = 'What is an LLM and how does Ollama run it locally?'
answer = llm.invoke(f'Q: {question}\nA:')
print('---')
print(answer.content)
# Out:
# I don't have any information about an "Ollama" or a connection between "LangChain" and such a entity. Can you please provide more context or clarify what you are referring to?
# ---
# An LLM (Large Language Model) refers to a type of artificial intelligence (AI) model that is specifically designed for natural language processing. These models are trained on vast amounts of text data, which enables them to learn patterns, relationships, and context in language.
#
# One example of an LLM is Ollama, which is a large language model developed by Meta AI. Ollama is a transformer-based model that uses self-attention mechanisms to process sequential input data, such as text or speech.
#
# To run an LLM like Ollama locally on your computer or device, you typically need to:
#
# ...
